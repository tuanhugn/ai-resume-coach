# %% [markdown]
# <a href="https://colab.research.google.com/github/tuanhugn/ai-resume-coach/blob/main/core/Core_Engine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mở cổng kết nối GG Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Khai báo PATH đến folder Project
import os
PROJECT_PATH = '/content/drive/MyDrive/AI_Resume_Project'

# %%
#Chuyển Colab vào thư mục này
os.chdir(PROJECT_PATH)
print(os.getcwd())
# Out:
# /content/drive/MyDrive/AI_Resume_Project

# %% [markdown]
# Xử lý PDF CV ✅

# %%
import pdfplumber
import pytesseract
from pdf2image import convert_from_path
import os

def extract_text_from_pdf(pdf_path):

  if not os.path.exists(pdf_path):
    return(f"Khong ton tai file PDF: {pdf_path}")


  text = ""

  try:
    with pdfplumber.open(pdf_path) as pdf:
      for i,page in enumerate(pdf.pages):
        page_text = page.extract_text()

        if page_text:
          text += f"\n ---Noi dung trang {i+1} --- \n"
          text += page_text + "\n"

  except Exception as e:
    return f"Loi {str(e)} trong qua trinh doc"

  text = text.strip()

  if len(text) < 1000:
    print("Kich hoat ORC")
    try:
      images = convert_from_path(pdf_path)
      orc_text = ""
      for image in images:
        text_from_img = pytesseract.image_to_string(image,lang = 'vie+eng')
        orc_text += text_from_img + '\n'
      return orc_text.strip()

    except Exception as e:
      return f"Loi {str(e)} trong qua trinh doc"

  return text

# %%
TEST_PDF_PATH = "data_input/cv_test_1.pdf"

raw_cv_text = extract_text_from_pdf(TEST_PDF_PATH)
print(raw_cv_text)
# Out:
# Kich hoat ORC
# 2/22/26, 10:08 AM
#
# https://scontent.fhan14-1.fna.focdn.net/v/t39.30808-6/635559027_765665513268483_8735973860927389602_n.jpg?_nc_cat=107&ccb=1-7&_nc_sid...
#
# 635559027_765665513268483_8735973860927389602_n.jpg (10361476)
#
# Mm. ae
#
# e Research Engineer with over 5 years experience in applying ML/AI for scientific research data,
# focusing on scalability and real-world applications.
#
# e Open-source projects with 100+ GitHub stars, top-tier publications with 400+ citations.
#
# e Expertise: Python, PyTorch, Linux, Distributed Systems, Machine Learning, GPUs
# EDUCATION
#
# University of Erlangen-Nuremberg, Germany Ph.D., Electrical Engineering | Oct 2025
# Focus: ML-driven Point Cloud Processing | Advisor: Prof. Dr.-Ing. André Kaup
#
# Polytechnic Institute of Paris, France M.Sc., Electrical Engineering | Nov 2020
# Focus: Image, Video, Machine Learning| GPA: 16.7/20 (Highest Honors)
#
# HUST University, Vietnam B.Eng., Electrical Engineering | Mar 2019
# ...
